# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import json
import re # Necessário para expressões regulares na lógica antiga

def obter_generos_oscar(anos):
    todos_os_generos = []

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    for ano in anos:
        url = f"https://www.imdb.com/pt/event/ev0000003/{ano}/1/?ref_=ev_acd_tl_yr_1"
        print(f"\nColetando dados para o Oscar de {ano} - URL: {url}")

        dados_ano = {
            'Ano': ano,
            'Gênero do Melhor Filme': 'Não encontrado',
            'Gênero do Melhor Diretor': 'Não encontrado',
            'Gênero do Melhor Ator': 'Não encontrado',
            'Gênero do Melhor Atriz': 'Não encontrado',
            'Gênero do Melhor Ator Coadjuvante': 'Não encontrado',
            'Gênero do Melhor Atriz Coadjuvante': 'Não encontrado'
        }

        # Mapeamento de categorias para data-testid (layout novo) ou IDs de span (layout antigo)
        # Os IDs de span foram observados para anos como 1995
        categorias_map = {
            'Melhor Filme': {
                'testid': 'BestMotionPictureoftheYear'
            },
            'Melhor Diretor': {
                'testid': 'BestAchievementinDirecting',
                'old_id': 'oscar_best_director'
            },
            'Melhor Ator': {
                'testid': 'BestPerformancebyanActorinaLeadingRole',
                'old_id': 'oscar_best_actor_in_a_leading_role'
            },
            'Melhor Atriz': {
                'testid': 'BestPerformancebyanActressinaLeadingRole',
                'old_id': 'oscar_best_actress_in_a_leading_role'
            },
            'Melhor Ator Coadjuvante': {
                'testid': 'BestPerformancebyanActorinaSupportingRole',
                'old_id': 'oscar_best_actor_in_a_supporting_role'
            },
            'Melhor Atriz Coadjuvante': {
                'testid': 'BestPerformancebyanActressinaSupportingRole',
                'old_id': 'oscar_best_actress_in_a_supporting_role'
            }
        }
        
        encontrou_algum_dado_no_ano = False

        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            # --- Lógica para layout pós-2004 (ano >= 2005) ---
            if ano >= 2005:
                print(f"    Aplicando lógica para layout pós-2004 (ano >= 2005)...")
                for categoria_nome, ids in categorias_map.items():
                    data_testid_val = ids.get('testid')
                    if not data_testid_val: continue

                    print(f"      Buscando contêiner para a categoria: '{categoria_nome}' com data-testid: '{data_testid_val}'")
                    category_container = soup.find('section', {'data-testid': data_testid_val})

                    if category_container:
                        movie_link_tag = None
                        content_container = category_container.find('div', class_='ipc-metadata-list-item__content-container')
                        
                        if content_container:
                            if categoria_nome == 'Melhor Filme':
                                movie_link_tag = content_container.find('a', href=re.compile(r'/title/'))
                            else:
                                all_links_in_content = content_container.find_all('a', href=True)
                                for link in all_links_in_content:
                                    if '/title/' in link['href']:
                                        movie_link_tag = link
                                        break
                        
                        if movie_link_tag:
                            movie_url = "https://www.imdb.com" + movie_link_tag['href']
                            genero_encontrado = _extrair_generos_do_filme(movie_url, headers)
                            dados_ano[f'Gênero do {categoria_nome}'] = genero_encontrado
                            if genero_encontrado != 'Não encontrado':
                                encontrou_algum_dado_no_ano = True
                            print(f"        Gênero para '{categoria_nome}': {genero_encontrado}")
                        else:
                            print(f"        Link de filme para '{categoria_nome}' NÃO encontrado para o Oscar de {ano}.")
                    else:
                        print(f"        Contêiner da categoria para '{categoria_nome}' (data-testid='{data_testid_val}') NÃO encontrado.")
            
            # --- Lógica para layout pré-2005 (ano < 2005) ---
            else:
                print(f"    Aplicando lógica para layout antigo do Oscar (ano < 2005)...")
                for categoria_nome, ids in categorias_map.items():
                    # Para anos antigos, o "Melhor Filme" ainda pode usar o layout mais novo
                    # ou uma estrutura muito específica. Re-validando o Melhor Filme aqui
                    # com a estrutura de link ipc-title-link-wrapper
                    if categoria_nome == 'Melhor Filme':
                        # Esta parte é um pouco redundante mas garante que tentamos o Melhor Filme com o ipc-
                        film_link_element_bp = soup.find('a', class_='ipc-title-link-wrapper', href=re.compile(r'/title/'))
                        if film_link_element_bp:
                            movie_url = "https://www.imdb.com" + film_link_element_bp['href']
                            genero_encontrado = _extrair_generos_do_filme(movie_url, headers)
                            dados_ano['Gênero do Melhor Filme'] = genero_encontrado
                            if genero_encontrado != 'Não encontrado':
                                encontrou_algum_dado_no_ano = True
                            print(f"        Gênero para 'Melhor Filme': {genero_encontrado} (via ipc-link-wrapper)")
                            continue # Vai para a próxima categoria se Melhor Filme foi encontrado
                        else:
                            print(f"        Melhor Filme NÃO encontrado para o ano {ano} usando ipc-link-wrapper na lógica antiga.")


                    # Para as demais categorias (pessoa), priorizar a busca por ID no span
                    old_id_val = ids.get('old_id')
                    if not old_id_val: continue # Se não tem old_id para a categoria

                    print(f"      Buscando cabeçalho para a categoria: '{categoria_nome}' com ID: '{old_id_val}'")
                    category_header_span = soup.find('span', id=old_id_val)
                    
                    movie_link_tag = None
                    if category_header_span:
                        # Tentar encontrar o link do filme associado ao vencedor
                        # (Geralmente vem DEPOIS do link da pessoa, no mesmo nível ou num pai próximo)
                        # Busca o primeiro link de título APÓS o span do ID da categoria
                        movie_link_tag = category_header_span.find_next('a', href=re.compile(r'/title/'))
                        
                        if not movie_link_tag:
                            # Se não encontrou o link de título imediatamente, pode estar em um elemento pai
                            # do span da categoria, e o link do filme está em algum lugar dentro desse pai.
                            # Esta é uma busca mais ampla, pode pegar o primeiro link de título geral da seção.
                            parent_div_or_table = category_header_span.find_parent('div') or category_header_span.find_parent('table')
                            if parent_div_or_table:
                                movie_link_tag = parent_div_or_table.find('a', href=re.compile(r'/title/'))

                    if movie_link_tag:
                        movie_url = "https://www.imdb.com" + movie_link_tag['href']
                        genero_encontrado = _extrair_generos_do_filme(movie_url, headers)
                        dados_ano[f'Gênero do {categoria_nome}'] = genero_encontrado
                        if genero_encontrado != 'Não encontrado':
                            encontrou_algum_dado_no_ano = True
                        print(f"        Gênero para '{categoria_nome}': {genero_encontrado} (via ID no span/next)")
                    else:
                        print(f"        Link de filme para '{categoria_nome}' NÃO encontrado para o Oscar de {ano}.")
            
            # Adiciona os dados do ano somente se algo foi encontrado ou se queremos registrar o ano mesmo vazio
            if encontrou_algum_dado_no_ano or ano < 2005: # Inclui anos antigos mesmo que nada seja encontrado inicialmente para depuração
                todos_os_generos.append(dados_ano)
            else:
                print(f"  Nenhum dado de gênero encontrado para o ano {ano}. Ano não adicionado aos resultados.")

        except requests.exceptions.HTTPError as e:
            print(f"Erro HTTP ao acessar a URL do Oscar {ano}: {e}")
        except requests.exceptions.RequestException as e:
            print(f"Erro de requisição ao acessar a URL do Oscar {ano}: {e}")
        except Exception as e:
            print(f"Erro inesperado ao processar o Oscar de {ano}: {e}")
        finally:
            time.sleep(2) # Delay entre as páginas do Oscar

    df_generos = pd.DataFrame(todos_os_generos)
    return df_generos

# Função auxiliar para extrair gêneros de uma página de filme
def _extrair_generos_do_filme(film_url: str, headers: dict) -> str:
    print(f"      Acessando página do filme para gêneros: {film_url}")
    try:
        film_response = requests.get(film_url, headers=headers)
        film_response.raise_for_status()
        film_soup = BeautifulSoup(film_response.text, 'html.parser')
        genres = []

        # PRIORIDADE: Buscar gêneros do JSON-LD
        script_tag = film_soup.find('script', type='application/ld+json')
        if script_tag:
            try:
                json_data = json.loads(script_tag.string)
                if 'genre' in json_data:
                    if isinstance(json_data['genre'], list):
                        genres = json_data['genre']
                    elif isinstance(json_data['genre'], str):
                        genres = [json_data['genre']]
            except json.JSONDecodeError as e:
                print(f"      Erro ao decodificar JSON-LD da página do filme ({film_url}): {e}")
            except Exception as e:
                print(f"      Erro inesperado ao processar JSON-LD da página do filme ({film_url}): {e}")

        # Fallback para extração de HTML caso o JSON-LD não funcione ou não tenha o gênero
        if not genres:
            print(f"      JSON-LD não continha gêneros ou falhou. Tentando extrair do HTML...")
            # Lógica para layouts de filmes mais recentes (data-testid='genres')
            genres_container = film_soup.find('div', {'data-testid': 'genres'})
            if genres_container:
                genre_tags = genres_container.find_all('span', class_='ipc-chip__text')
                for tag in genre_tags:
                    genres.append(tag.get_text(strip=True))
            
            # Lógica para layouts de filmes mais antigos (see-more subtext ou itemprop="genre")
            if not genres:
                old_genres_div = film_soup.find('div', class_='see-more subtext')
                if not old_genres_div:
                    old_genres_div = film_soup.find('div', id='title-overview-widget')
                    if old_genres_div:
                        genre_items = old_genres_div.find_all('span', itemprop='genre')
                        for item in genre_items:
                            if item.text.strip():
                                genres.append(item.text.strip())
                if not genres and old_genres_div:
                    genre_links = old_genres_div.find_all('a', href=re.compile(r'/genre/'))
                    for link in genre_links:
                        genres.append(link.get_text(strip=True))
                
                # Tentativa final: Gêneros diretamente após um cabeçalho "Genres" ou "Gêneros"
                if not genres:
                    genres_header = film_soup.find(['h4', 'div', 'b', 'span'], string=re.compile(r'Gêneros|Genres', re.IGNORECASE))
                    if genres_header:
                        next_element = genres_header.find_next_sibling()
                        if next_element:
                            genre_links_alt = next_element.find_all('a', href=re.compile(r'/genre/'))
                            for link in genre_links_alt:
                                genres.append(link.get_text(strip=True))
        
        if genres:
            return ", ".join(genres)
        else:
            return "Não encontrado"
    
    except requests.exceptions.RequestException as e:
        print(f"      Erro ao acessar URL do filme para gêneros ({film_url}): {e}")
        return "Erro de Requisição"
    except Exception as e:
        print(f"      Erro inesperado ao processar gêneros do filme ({film_url}): {e}")
        return "Erro Inesperado"
    finally:
        time.sleep(1.5) # Delay entre as requisições de filme

# Exemplo de uso
# Agora vamos focar nos anos anteriores a 2005
anos_para_coletar = range(1929, 2026) 
df_generos_vencedores = obter_generos_oscar(anos_para_coletar)

# Salvar os dados
df_generos_vencedores.to_csv('oscar_generos_vencedores_pre_2005.csv', index=False)
print("\nDados de gênero salvos em 'oscar_generos_vencedores_pre_2005.csv'")
print(f"Total de anos com dados de gênero coletados: {len(df_generos_vencedores)}")

print("\n--- Primeiras 25 linhas dos dados de Gênero coletados ---")
print(df_generos_vencedores.head(25).to_markdown(index=False))
# Out:
# Coletando dados para o Oscar de 1929 - URL: https://www.imdb.com/pt/event/ev0000003/1929/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt
?ref_=ev_nom
#         Gênero para 'Melhor Ator': Drama (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz' com ID: 'oscar_best_actress_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0040495/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Drama (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator Coadjuvante' com ID: 'oscar_best_actor_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0040897/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Aventura, Drama, Faroeste (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz Coadjuvante' com ID: 'oscar_best_actress_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0040506/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Ação, Policial, Drama (via ID no span/next)
#
# Coletando dados para o Oscar de 1950 - URL: https://www.imdb.com/pt/event/ev0000003/1950/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0041452/?ref_=ev_nom
#         Gênero para 'Melhor Filme': Drama, Romance (via ipc-link-wrapper)
#       Buscando cabeçalho para a categoria: 'Melhor Diretor' com ID: 'oscar_best_director'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0041587/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Comédia, Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator' com ID: 'oscar_best_actor_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0041113/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Drama, Filme noir (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz' com ID: 'oscar_best_actress_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0041452/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator Coadjuvante' com ID: 'oscar_best_actor_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0041996/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Drama, Guerra (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz Coadjuvante' com ID: 'oscar_best_actress_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0041113/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Drama, Filme noir (via ID no span/next)
#
# Coletando dados para o Oscar de 1951 - URL: https://www.imdb.com/pt/event/ev0000003/1951/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0043014/?ref_=ev_nom
#         Gênero para 'Melhor Filme': Drama, Filme noir (via ipc-link-wrapper)
#       Buscando cabeçalho para a categoria: 'Melhor Diretor' com ID: 'oscar_best_director'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0042192/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Drama (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator' com ID: 'oscar_best_actor_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0042367/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Aventura, Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz' com ID: 'oscar_best_actress_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0042276/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Comédia, Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator Coadjuvante' com ID: 'oscar_best_actor_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0042192/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Drama (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz Coadjuvante' com ID: 'oscar_best_actress_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0042546/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Comédia, Drama, Fantasia (via ID no span/next)
#
# Coletando dados para o Oscar de 1952 - URL: https://www.imdb.com/pt/event/ev0000003/1952/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0044081/?ref_=ev_nom
#         Gênero para 'Melhor Filme': Drama (via ipc-link-wrapper)
#       Buscando cabeçalho para a categoria: 'Melhor Diretor' com ID: 'oscar_best_director'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0043924/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator' com ID: 'oscar_best_actor_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0043265/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Aventura, Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz' com ID: 'oscar_best_actress_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0044081/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Drama (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator Coadjuvante' com ID: 'oscar_best_actor_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0044081/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Drama (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz Coadjuvante' com ID: 'oscar_best_actress_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0044081/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Drama (via ID no span/next)
#
# Coletando dados para o Oscar de 1953 - URL: https://www.imdb.com/pt/event/ev0000003/1953/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0044391/?ref_=ev_nom
#         Gênero para 'Melhor Filme': Drama, Romance (via ipc-link-wrapper)
#       Buscando cabeçalho para a categoria: 'Melhor Diretor' com ID: 'oscar_best_director'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0045061/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Comédia, Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator' com ID: 'oscar_best_actor_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0044706/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Drama, Suspense, Faroeste (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz' com ID: 'oscar_best_actress_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0044509/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator Coadjuvante' com ID: 'oscar_best_actor_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0045296/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Biografia, Drama, História (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz Coadjuvante' com ID: 'oscar_best_actress_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0044391/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Drama, Romance (via ID no span/next)
#
# Coletando dados para o Oscar de 1954 - URL: https://www.imdb.com/pt/event/ev0000003/1954/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0045943/?ref_=ev_nom
#         Gênero para 'Melhor Filme': Drama, História (via ipc-link-wrapper)
#       Buscando cabeçalho para a categoria: 'Melhor Diretor' com ID: 'oscar_best_director'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0045793/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Drama, Romance, Guerra (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator' com ID: 'oscar_best_actor_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0046359/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Comédia, Drama, Guerra (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz' com ID: 'oscar_best_actress_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0046250/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Comédia, Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator Coadjuvante' com ID: 'oscar_best_actor_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0045793/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Drama, Romance, Guerra (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz Coadjuvante' com ID: 'oscar_best_actress_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0045793/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Drama, Romance, Guerra (via ID no span/next)
#
# Coletando dados para o Oscar de 1955 - URL: https://www.imdb.com/pt/event/ev0000003/1955/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0047296/?ref_=ev_nom
#         Gênero para 'Melhor Filme': Policial, Drama, Suspense (via ipc-link-wrapper)
#       Buscando cabeçalho para a categoria: 'Melhor Diretor' com ID: 'oscar_best_director'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0047296/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Policial, Drama, Suspense (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator' com ID: 'oscar_best_actor_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0047296/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Policial, Drama, Suspense (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz' com ID: 'oscar_best_actress_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0046874/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Drama, Musical (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator Coadjuvante' com ID: 'oscar_best_actor_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0046754/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Policial, Drama, Mistério (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz Coadjuvante' com ID: 'oscar_best_actress_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0047296/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Policial, Drama, Suspense (via ID no span/next)
#
# Coletando dados para o Oscar de 1956 - URL: https://www.imdb.com/pt/event/ev0000003/1956/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0048563/?ref_=ev_nom
#         Gênero para 'Melhor Filme': Comédia, Drama, Romance (via ipc-link-wrapper)
#       Buscando cabeçalho para a categoria: 'Melhor Diretor' com ID: 'oscar_best_director'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0048356/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator' com ID: 'oscar_best_actor_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0048356/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz' com ID: 'oscar_best_actress_in_a_leading_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0048563/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Comédia, Drama, Romance (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Ator Coadjuvante' com ID: 'oscar_best_actor_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0048380/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Comédia, Drama, Guerra (via ID no span/next)
#       Buscando cabeçalho para a categoria: 'Melhor Atriz Coadjuvante' com ID: 'oscar_best_actress_in_a_supporting_role'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0048028/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Drama (via ID no span/next)
#
# Coletando dados para o Oscar de 1957 - URL: https://www.imdb.com/pt/event/ev0000003/1957/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout antigo do Oscar (ano < 2005)...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0049778/?ref_=ev_nom
#         Gênero para 'Melhor Filme': Biografia, Drama, Esportes (via ipc-link-wrapper)
#       Buscando cabeçalho para a categoria: 'Melhor Diretor' com ID: 'oscar_best_director'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt0049261/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Drama, Faroeste (via ID no span/next)
# ...
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt7286456/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Policial, Drama, Suspense
#       Buscando contêiner para a categoria: 'Melhor Atriz' com data-testid: 'BestPerformancebyanActressinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt7549996/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Biografia, Drama, Musical
#       Buscando contêiner para a categoria: 'Melhor Ator Coadjuvante' com data-testid: 'BestPerformancebyanActorinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt7131622/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Comédia, Drama
#       Buscando contêiner para a categoria: 'Melhor Atriz Coadjuvante' com data-testid: 'BestPerformancebyanActressinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt7653254/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Drama, Romance
#
# Coletando dados para o Oscar de 2021 - URL: https://www.imdb.com/pt/event/ev0000003/2021/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout pós-2004 (ano >= 2005)...
#       Buscando contêiner para a categoria: 'Melhor Filme' com data-testid: 'BestMotionPictureoftheYear'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt9770150/?ref_=ev_i_1
#         Gênero para 'Melhor Filme': Drama
#       Buscando contêiner para a categoria: 'Melhor Diretor' com data-testid: 'BestAchievementinDirecting'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt9770150/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Drama
#       Buscando contêiner para a categoria: 'Melhor Ator' com data-testid: 'BestPerformancebyanActorinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt10272386/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Drama, Mistério
#       Buscando contêiner para a categoria: 'Melhor Atriz' com data-testid: 'BestPerformancebyanActressinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt9770150/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Drama
#       Buscando contêiner para a categoria: 'Melhor Ator Coadjuvante' com data-testid: 'BestPerformancebyanActorinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt9784798/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Biografia, Drama, História
#       Buscando contêiner para a categoria: 'Melhor Atriz Coadjuvante' com data-testid: 'BestPerformancebyanActressinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt10633456/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Drama
#
# Coletando dados para o Oscar de 2022 - URL: https://www.imdb.com/pt/event/ev0000003/2022/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout pós-2004 (ano >= 2005)...
#       Buscando contêiner para a categoria: 'Melhor Filme' com data-testid: 'BestMotionPictureoftheYear'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt10366460/?ref_=ev_i_1
#         Gênero para 'Melhor Filme': Comédia, Drama, Musical
#       Buscando contêiner para a categoria: 'Melhor Diretor' com data-testid: 'BestAchievementinDirecting'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt10293406/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Drama, Faroeste
#       Buscando contêiner para a categoria: 'Melhor Ator' com data-testid: 'BestPerformancebyanActorinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt9620288/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Biografia, Drama, Esportes
#       Buscando contêiner para a categoria: 'Melhor Atriz' com data-testid: 'BestPerformancebyanActressinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt9115530/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Biografia, Drama, Romance
#       Buscando contêiner para a categoria: 'Melhor Ator Coadjuvante' com data-testid: 'BestPerformancebyanActorinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt10366460/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Comédia, Drama, Musical
#       Buscando contêiner para a categoria: 'Melhor Atriz Coadjuvante' com data-testid: 'BestPerformancebyanActressinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt3581652/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Policial, Drama, Musical
#
# Coletando dados para o Oscar de 2023 - URL: https://www.imdb.com/pt/event/ev0000003/2023/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout pós-2004 (ano >= 2005)...
#       Buscando contêiner para a categoria: 'Melhor Filme' com data-testid: 'BestMotionPictureoftheYear'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt6710474/?ref_=ev_i_1
#         Gênero para 'Melhor Filme': Ação, Aventura, Comédia
#       Buscando contêiner para a categoria: 'Melhor Diretor' com data-testid: 'BestAchievementinDirecting'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt6710474/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Ação, Aventura, Comédia
#       Buscando contêiner para a categoria: 'Melhor Ator' com data-testid: 'BestPerformancebyanActorinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt13833688/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Drama
#       Buscando contêiner para a categoria: 'Melhor Atriz' com data-testid: 'BestPerformancebyanActressinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt6710474/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Ação, Aventura, Comédia
#       Buscando contêiner para a categoria: 'Melhor Ator Coadjuvante' com data-testid: 'BestPerformancebyanActorinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt6710474/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Ação, Aventura, Comédia
#       Buscando contêiner para a categoria: 'Melhor Atriz Coadjuvante' com data-testid: 'BestPerformancebyanActressinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt6710474/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Ação, Aventura, Comédia
#
# Coletando dados para o Oscar de 2024 - URL: https://www.imdb.com/pt/event/ev0000003/2024/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout pós-2004 (ano >= 2005)...
#       Buscando contêiner para a categoria: 'Melhor Filme' com data-testid: 'BestMotionPictureoftheYear'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt15398776/?ref_=ev_i_1
#         Gênero para 'Melhor Filme': Biografia, Drama, História
#       Buscando contêiner para a categoria: 'Melhor Diretor' com data-testid: 'BestAchievementinDirecting'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt15398776/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Biografia, Drama, História
#       Buscando contêiner para a categoria: 'Melhor Ator' com data-testid: 'BestPerformancebyanActorinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt15398776/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Biografia, Drama, História
#       Buscando contêiner para a categoria: 'Melhor Atriz' com data-testid: 'BestPerformancebyanActressinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt14230458/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Comédia, Drama, Romance
#       Buscando contêiner para a categoria: 'Melhor Ator Coadjuvante' com data-testid: 'BestPerformancebyanActorinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt15398776/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Biografia, Drama, História
#       Buscando contêiner para a categoria: 'Melhor Atriz Coadjuvante' com data-testid: 'BestPerformancebyanActressinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt14849194/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Comédia, Drama
#
# Coletando dados para o Oscar de 2025 - URL: https://www.imdb.com/pt/event/ev0000003/2025/1/?ref_=ev_acd_tl_yr_1
#     Aplicando lógica para layout pós-2004 (ano >= 2005)...
#       Buscando contêiner para a categoria: 'Melhor Filme' com data-testid: 'BestMotionPictureoftheYear'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt28607951/?ref_=ev_i_1
#         Gênero para 'Melhor Filme': Comédia, Drama, Romance
#       Buscando contêiner para a categoria: 'Melhor Diretor' com data-testid: 'BestAchievementinDirecting'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt28607951/?ref_=ev_nom
#         Gênero para 'Melhor Diretor': Comédia, Drama, Romance
#       Buscando contêiner para a categoria: 'Melhor Ator' com data-testid: 'BestPerformancebyanActorinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt8999762/?ref_=ev_nom
#         Gênero para 'Melhor Ator': Drama
#       Buscando contêiner para a categoria: 'Melhor Atriz' com data-testid: 'BestPerformancebyanActressinaLeadingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt28607951/?ref_=ev_nom
#         Gênero para 'Melhor Atriz': Comédia, Drama, Romance
#       Buscando contêiner para a categoria: 'Melhor Ator Coadjuvante' com data-testid: 'BestPerformancebyanActorinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt21823606/?ref_=ev_nom
#         Gênero para 'Melhor Ator Coadjuvante': Comédia, Drama
#       Buscando contêiner para a categoria: 'Melhor Atriz Coadjuvante' com data-testid: 'BestPerformancebyanActressinaSupportingRole'
#       Acessando página do filme para gêneros: https://www.imdb.com/pt/title/tt20221436/?ref_=ev_nom
#         Gênero para 'Melhor Atriz Coadjuvante': Policial, Drama, Musical
#
# Dados de gênero salvos em 'oscar_generos_vencedores_pre_2005.csv'
# Total de anos com dados de gênero coletados: 96
#
# --- Primeiras 25 linhas dos dados de Gênero coletados ---
# |   Ano | Gênero do Melhor Filme     | Gênero do Melhor Diretor   | Gênero do Melhor Ator       | Gênero do Melhor Atriz      | Gênero do Melhor Ator Coadjuvante   | Gênero do Melhor Atriz Coadjuvante   |
# |------:|:---------------------------|:---------------------------|:----------------------------|:----------------------------|:------------------------------------|:-------------------------------------|
# |  1929 | Aventura, Drama, Romance   | Não encontrado             | Drama, Romance, Guerra      | Drama, Romance              | Não encontrado                      | Não encontrado                       |
# |  1930 | Drama                      | Drama, História, Romance   | Drama, Faroeste             | Drama, Romance              | Não encontrado                      | Não encontrado                       |
# |  1931 | Drama, Faroeste            | Comédia, Drama, Família    | Policial, Drama, Romance    | Comédia, Drama              | Não encontrado                      | Não encontrado                       |
# |  1932 | Comédia, Drama             | Drama, Romance             | Drama, Família, Esportes    | Policial, Drama, Romance    | Não encontrado                      | Não encontrado                       |
